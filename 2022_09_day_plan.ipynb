# %%
'''
# 2022_09_01

    # 2022_09_01_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 07:40 - ready
            07:40 ~ 08:00 - breakfirst
            08:00 ~ 08:50 - deep_reinforcement_learning_book_read
            08:50 ~ 09:30 - go_to_work
            09:30 ~ 12:00 - optimum_design_class              

    # 2022_09_01_second
        # 12:00 ~ 18:00
            12:00 ~ 12:30 - optimum_design_class
            12:30 ~ 13:30 - lunch
            13:30 ~ 14:00 - deep_reinforcement_learning_book_read
            14:00 ~ 15:00 - CJK_meeting
            15:00 ~ 18:00 - car_research
            
    # 2022_09_01_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - girlfriend_meet


    # 2022_09_01_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - deep_reinfrocement_learning_ppt
        - meeting_fee_claim
        - zig_get
        - cae_how_to_do
        - CJK_ppt_ten_per_day
        - dental_clinic
        - Paris_Baguette
        - long_t_shirt
        - credit_card
'''

# %%
'''
# 2022_09_02

    # 2022_09_02_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - CJG_ppt
            07:00 ~ 07:30 - ready
            07:30 ~ 08:00 - breakfirst
            08:00 ~ 08:50 - CJG_ppt
            08:50 ~ 09:00 - go_to_work
            09:00 ~ 12:00 - car_research             

    # 2022_09_02_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - car_research
            
    # 2022_09_02_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 22:00 - deep_reinforcement_learning_book_read
            22:00 ~ 23:00 - go_to_home


    # 2022_09_02_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - deep_reinfrocement_learning_ppt
        - meeting_fee_claim
        - cae_how_to_do
        - CJK_ppt_ten_per_day
        - dental_clinic
        - Paris_Baguette
        - long_t_shirt
        - KTW_meeting_time
        - meeting_ParkYS
        - research_active_dayily_log
'''

# %%
'''
# 2022_09_03

    # 2022_09_03_first
        # 06:00 ~ 12:00
            06:00 ~ 10:30 - zzZ
            10:30 ~ 12:00 - ready_and_breakfirst
         
    # 2022_09_03_second
        # 12:00 ~ 18:00
            12:00 ~ 14:00 - dental_clinic
            14:00 ~ 15:00 - rest
            15:00 ~ 16:00 - read_book_deep_reinforcement_learning
            16:00 ~ 18:00 - girlfriend_call
            
            
    # 2022_09_03_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 22:00 - go_to_market
            22:00 ~ 24:00 - party_with_parents


    # 2022_09_03_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:00 - party_with_parents
            01:00 ~ 04:00 - girlfriend_call
            04:00 ~ 06:00 - zzZ
            
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - deep_reinfrocement_learning_ppt
        - meeting_fee_claim
        - cae_how_to_do
        - CJK_ppt_ten_per_day
        - Paris_Baguette
        - long_t_shirt
        - KTW_meeting_time
        - meeting_ParkYS
        - research_active_dayily_log
'''

# %%
'''
# 2022_09_04

    # 2022_09_04_first
        # 06:00 ~ 12:00
            06:00 ~ 11:00 - zzZ
            11:00 ~ 12:00 - ready_and_breakfirst
         
    # 2022_09_04_second
        # 12:00 ~ 18:00
            12:00 ~ 15:00 - go_to_cafe_read_book
            15:00 ~ 16:00 - girlfriend_call
            16:00 ~ 18:00 - read_book_deep_reinforcement_learning            
            
    # 2022_09_04_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - go_to_school
            21:00 ~ 24:00 - read_book_deep_reinforcement_learning


    # 2022_09_04_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:30 - girlfriend_call
            01:30 ~ 06:00 - zzZ

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - deep_reinfrocement_learning_ppt
        - meeting_fee_claim
        - cae_how_to_do
        - CJK_ppt_ten_per_day
        - Paris_Baguette
        - long_t_shirt
        - KTW_meeting_time
        - meeting_ParkYS
        - research_active_dayily_log
'''

# %%
'''
# 2022_09_05

    # 2022_09_05_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 07:30 - ready
            07:30 ~ 08:00 - breakfirst
            08:00 ~ 10:30 - deep_reinfrocement_learning_ppt
            10:50 ~ 12:00 - KTW_meeting
            
         
    # 2022_09_05_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 13:30 - PYS_meet
            13:30 ~ 17:20 - electronic_produch_lecture            
            17:20 ~ 18:00 - 3D_CAM_lecture

    # 2022_09_05_third
        # 18:00 ~ 24:00
            18:00 ~ 20:00 - 3D_CAM_lecture
            20:00 ~ 24:00 - honina


    # 2022_09_05_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:00 - honina
            01:00 ~ 06:00 - zzZ

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - deep_reinfrocement_learning_ppt
        - meeting_fee_claim
        - cae_how_to_do
        - CJK_ppt_ten_per_day
        - long_t_shirt
        - KTW_meeting_time
        - research_active_dayily_log
        - CJK_ppt_make_start
        - electronic_smart_phone_project
'''

# %%
'''
# 2022_09_06

    # 2022_09_06_first
        # 06:00 ~ 12:00
            06:00 ~ 10:00 - zzZ
            10:00 ~ 12:00 - ready
         
    # 2022_09_06_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 13:30 - CJG_meet
            13:30 ~ 14:20 - total_design_lecture            
            14:20 ~ 17:20 - Korea_lecture
            17:20 ~ 18:00 - dinner
            

    # 2022_09_06_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - deep_reinfrocement_learning_ppt
            19:00 ~ 21:00 - golf_lecture
            21:00 ~ 24:00 - deep_reinfrocement_learning_ppt
            
    # 2022_09_06_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - deep_reinfrocement_learning_ppt
        - cae_how_to_do
        - CJK_ppt_ten_per_day
        - long_t_shirt
        - research_active_dayily_log
        - CJK_ppt_make_start
        - electronic_smart_phone_project
        - golf_book_buy
        - korea_literature_project
'''

# %%
'''

# 2022_09_07

    # 2022_09_07_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - deep_reinfocement_learning_ppt
            09:00 ~ 12:00 - go_to_work
         
    # 2022_09_07_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 14:00 - deep_reinfocement_learning_ppt
            14:00 ~ 18:00 - ER_AGH_meeting           

    # 2022_09_07_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - girlfreind_meet
            21:00 ~ 24:00 - CJG_ppt
            
    # 2022_09_07_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - girlfreind_meet
            02:00 ~ 06:00 - zzZ

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - deep_reinfrocement_learning_ppt
        - long_t_shirt
        - research_active_dayily_log
        - CJK_ppt_make_109
        - electronic_smart_phone_project
        - total_design_meeting
        - korea_literature_project

'''

# %%
'''

# 2022_09_08

    # 2022_09_08_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 07:30 - ready to breakfirst
            07:30 ~ 08:00 - many_to_do_list
            08:00 ~ 08:30 - PYS_meeting
            08:30 ~ 12:00 - optimization_design_lecture
            
         
    # 2022_09_08_second
        # 12:00 ~ 18:00
            12:00 ~ 13:30 - CJG_ppt_make
            13:30 ~ 14:30 - lunch
            14:30 ~ 18:00 - car_research      

    # 2022_09_08_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - girlfreind_meet
            
    # 2022_09_08_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - parents_meet
            02:00 ~ 06:00 - zzZ

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - deep_reinfrocement_learning_4,5,7
        - long_t_shirt
        - CJK_ppt_make_109
        - electronic_smart_phone_project
        - total_design_meeting
        - korea_literature_project
        - Markov_Property
        - Q_learning_Algorithm
        - motion_equipment_contact
        - optimization_project_1,2,3
        
'''

# %%
'''

# 2022_09_09

    # 2022_09_09_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2022_09_09_second
        # 12:00 ~ 18:00
            12:00 ~ 18:00 - fmaily_meet    

    # 2022_09_09_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - fmaily_meet 
            
    # 2022_09_09_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - deep_reinfrocement_learning_4,5,7
        - long_t_shirt
        - CJK_ppt_make_109
        - electronic_smart_phone_project
        - total_design_meeting
        - korea_literature_project
        - Markov_Property
        - Q_learning_Algorithm
        - optimization_project_1,2,3
        
'''

# %%
'''

# 2022_09_10

    # 2022_09_10_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2022_09_10_second
        # 12:00 ~ 18:00
            12:00 ~ 18:00 - drive  

    # 2022_09_10_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - fmaily_meet 
            
    # 2022_09_10_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - deep_reinfrocement_learning_4,5,7
        - long_t_shirt
        - CJK_ppt_make_109
        - electronic_smart_phone_project
        - total_design_meeting
        - korea_literature_project
        - Markov_Property
        - Q_learning_Algorithm
        - optimization_project_1,2,3
        
'''

# %%
'''

# 2022_09_11

    # 2022_09_11_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2022_09_11_second
        # 12:00 ~ 18:00
            12:00 ~ 18:00 - drive  

    # 2022_09_11_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - fmaily_meet 
            
    # 2022_09_11_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - deep_reinfrocement_learning_4,5,7
        - long_t_shirt
        - CJK_ppt_make_109
        - electronic_smart_phone_project
        - total_design_meeting
        - korea_literature_project
        - Markov_Property
        - Q_learning_Algorithm
        - optimization_project_1,2,3
        
'''

# %%
'''

# 2022_09_12

    # 2022_09_12_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2022_09_12_second
        # 12:00 ~ 18:00
            12:00 ~ 18:00 - fmaily_meet   

    # 2022_09_12_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - drive
            
    # 2022_09_12_fourth
        # 24:00 ~ 06:00
            00:00 ~ 04:00 - drive
            04:00 ~ 06:00 - zzZ
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - deep_reinfrocement_learning_4,5,7
        - long_t_shirt
        - CJK_ppt_make_109
        - electronic_smart_phone_project
        - total_design_meeting
        - korea_literature_project
        - Markov_Property
        - Q_learning_Algorithm
        - optimization_project_1,2,3
        
'''

# %%
'''

# 2022_09_13

    # 2022_09_13_first
        # 06:00 ~ 12:00
            06:00 ~ 08:00 - zzZ
            08:00 ~ 09:00 - Markov_Property_study
            09:00 ~ 10:00 - Q_learning_Algorithm
            10:00 ~ 11:00 - Auto_meeting
            11:00 ~ 12:00 - CJK_ppt_make_109
            

    # 2022_09_13_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch   
            13:00 ~ 14:30 - total_design_meeting
            14:30 ~ 17:30 - Korea_lecture
            17:30 ~ 18:00 - dinner
            

    # 2022_09_13_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - honina
            19:00 ~ 21:00 - golf
            21:00 ~ 24:00 - deep_learning_study
            
            
    # 2022_09_13_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            

    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinfrocement_learning_4,5,7
        - long_t_shirt
        - CJK_ppt_make_109
        - electronic_smart_phone_project
        - total_design_meeting
        - korea_literature_project
        - optimization_project_1,2,3
        - tire_wear_thesis_patent_search
        - picnic_plan

'''

# %%
'''

# 2022_09_14

    # 2022_09_14_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - ready_and_breakfirst
            07:00 ~ 09:00 - optimization_project_1,2,3
            09:00 ~ 12:00 - car_research_and_read_book
            

    # 2022_09_14_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch_with_honi  
            13:00 ~ 18:00 - car_research_and_read_book
            

    # 2022_09_14_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner_with_honi
            19:00 ~ 21:00 - Chinese_class_and_read_book
            21:00 ~ 24:00 - deep_learning_study_and_ppt_make
            
            
    # 2022_09_14_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - girlfriend_fight
            

    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinfrocement_learning_4,5,7
        - long_t_shirt
        - CJK_ppt_make_109
        - electronic_smart_phone_project
        - total_design_meeting
        - korea_literature_project
        - optimization_project_1,2,3
        - tire_wear_thesis_patent_search
        - picnic_plan
        - YSJ_project_cae_needed

'''

# %%
'''

# 2022_09_15

    # 2022_09_15_first
        # 06:00 ~ 12:00
            06:00 ~ 08:30 - zzZ
            08:30 ~ 09:30 - PYS_meeting
            09:30 ~ 12:00 - optimization_design_lecture
            

    # 2022_09_15_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch_with_honi  
            13:00 ~ 14:00 - deep_reinfrocement_learning_ppt_make
            14:00 ~ 16:00 - AGH_meetign
            16:00 ~ 18:00 - CJG_ppt_make
            

    # 2022_09_15_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner_with_honi
            19:00 ~ 24:00 - talk_with_honi
            
            
    # 2022_09_15_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:00 - plan_correct
            01:00 ~ 06:00 - zzZ
                   

    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinforcement_learning_4,5,7
        - deep_reinforcement_learning_review
        - CJK_ppt_check
        - electronic_smart_phone_chagrined_process_study
        - total_design_thesis_and_patent_find
        - korea_literature_project
        - optimization_project_1,3,5
        - ansys_and_pneumatic_study
        - linux_download_needed_AGH

'''

# %%
'''

# 2022_09_16

    # 2022_09_16_first
        # 06:00 ~ 12:00
            06:00 ~ 08:30 - zzZ
            08:30 ~ 09:00 - ready_and_breakfirst_with_honina_needed
            09:00 ~ 12:00 - car_reasearch


    # 2022_09_16_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch 
            13:00 ~ 18:00 - car_research
            

    # 2022_09_16_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 20:00 - hair_cut
            20:00 ~ 21:00 - honina_katalk
            21:00 ~ 24:00 - deep_reinfrocement_learning_youtube_lecture
            
            
            
    # 2022_09_16_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - deep_reinfrocement_learning_youtube_lecture
            02:00 ~ 06:00 - zzZ
                   

    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinforcement_learning_4,5,7
        - deep_reinforcement_learning_review
        - electronic_smart_phone_chagrined_process_study
        - total_design_thesis_and_patent_find
        - korea_literature_project
        - optimization_project_1,3,5
        - ansys_and_pneumatic_study
        - linux_download_needed_AGH
        - optimization_lecture_4,5

'''

# %%
'''

# 2022_09_17

    break_up_with_girlfriend

    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinforcement_learning_4,5,7
        - deep_reinforcement_learning_review
        - electronic_smart_phone_chagrined_process_study
        - total_design_thesis_and_patent_find
        - korea_literature_project
        - optimization_project_1,3,5
        - ansys_and_pneumatic_study
        - linux_download_needed_AGH
        - optimization_lecture_4,5

'''

# %%
'''

# 2022_09_18

    # 2022_09_18_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2022_09_18_second
        # 12:00 ~ 18:00
            12:00 ~ 14:00 - zzZ
            14:00 ~ 15:00 - breakfirst_and_lunch
            15:00 ~ 18:00 - theis_and_patent_find
            
    # 2022_09_18_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - deep_reinfrocement_learning_read_book
             
    # 2022_09_18_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:00 - total_design_thesis_and_patent_meeting
            01:00 ~ 01:30 - CJG_ppt_check
            01:30 ~ 02:30 - KTW_meeting_ppt_make
                   

    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinforcement_learning_4,5,7
        - deep_reinforcement_learning_review
        - electronic_smart_phone_chagrined_process_study
        - total_design_thesis_and_patent_find
        - optimization_project_1,3,5
        - ansys_and_pneumatic_study
        - linux_download_needed_AGH
        - optimization_lecture_4,5
        - KTW_meeting_ppt_make
        - CJG_ppt_check

'''

# %%
'''

# 2022_09_19

    # 2022_09_19_first
        # 06:00 ~ 12:00
            06:00 ~ 08:00 - zzZ
            08:00 ~ 10:30 - deep_reinfrocement_learning_read_book
            10:30 ~ 12:00 - Auto_testing_meeting
            

    # 2022_09_19_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch_with_YSJ
            13:00 ~ 13:30 - PYS_meet
            13:30 ~ 17:30 - electronic_smart_phone_chagrined_lecture
            17:30 ~ 18:00 - 3DCAM_lecture
            

    # 2022_09_19_third
        # 18:00 ~ 24:00
            18:00 ~ 19:50 - 3DCAM_lecture
            19:50 ~ 21:00 - dinner
            21:00 ~ 24:00 - deep_reinfrocement_learning_read_book
            
             
    # 2022_09_19_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:00 - deep_reinfrocement_learning_read_book
            01:00 ~ 06:00 - zzZ
            
                   

    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinforcement_learning_4,5,7
        - deep_reinforcement_learning_review
        - electronic_smart_phone_chagrined_process_study
        - optimization_project_1,3,5
        - ansys_and_pneumatic_study
        - linux_download_needed_AGH
        - optimization_lecture_4,5
        - total_design_thesis_and_patent_meeting_ppt_make
        - student_reward_document_send
        - product_buy_request

'''

# %%
'''

# 2022_09_20

    # 2022_09_20_first
        # 06:00 ~ 12:00
            06:00 ~ 06:30 - ready
            06:30 ~ 08:30 - deep_reinfrocement_learning_read_book
            08:30 ~ 09:00 - breakfirst
            09:00 ~ 12:00 - deep_reinfrocement_learning_read_book
            
            

    # 2022_09_20_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 13:30 - meeting_ready
            13:30 ~ 14:30 - total_design_meeting_with_KTW
            14:30 ~ 17:30 - korea_literature_walk_lecture
            17:30 ~ 18:00 - nahyeon_meet
            

    # 2022_09_20_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - nahyeon_meet
            19:00 ~ 21:00 - golf_lecture
            21:00 ~ 22:00 - dinner
            22:00 ~ 23:00 - CJG_send_email_and_download_file
            23:00 ~ 24:00 - total_design_meeting
            

    # 2022_09_20_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:00 - deep_reinfrocement_learning_read_book
            01:00 ~ 06:00 - zzZ
            
                   

    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinforcement_learning_4,5,7
        - deep_reinforcement_learning_review
        - optimization_project_1,3,5
        - ansys_and_pneumatic_study
        - linux_download_needed_AGH
        - optimization_lecture_4,5
        - CJG_student_reward_document_send
        - product_buy_request
        - AGH_ppt_make
        - CJG_meeting_ready
        - korea_literature_walk_project_2022_09_26

'''

# %%
'''

# 2022_09_21

    # 2022_09_21_first
        # 06:00 ~ 12:00
            06:00 ~ 06:30 - ready
            06:30 ~ 08:30 - deep_reinfrocement_learning_read_book
            08:30 ~ 09:00 - breakfirst
            09:00 ~ 12:00 - car_research
            
            
    # 2022_09_21_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - car_research
            

    # 2022_09_21_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 23:00 - deep_reinfrocement_learning_read_book_and_make_ppt
            23:00 ~ 24:00 - zzZ
            
            

    # 2022_09_21_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            

    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinforcement_learning_4,5,7
        - deep_reinforcement_learning_review
        - optimization_project_1,3,5
        - ansys_and_pneumatic_study
        - linux_download_needed_AGH
        - optimization_lecture_4,5
        - CJG_student_reward_document_send
        - product_buy_request
        - AGH_ppt_make
        - CJG_meeting_ready
        - korea_literature_walk_project_2022_09_26
        - KTW_research_fee_change
        - tire_wear_predict_human_NN_study

'''

# %%
'''

# 2022_09_22

    # 2022_09_22_first
        # 06:00 ~ 12:00
            06:00 ~ 06:30 - ready
            06:30 ~ 09:00 - deep_reinfrocement_learning_read_book_and_make_ppt
            09:00 ~ 09:30 - breakfirst
            09:30 ~ 12:00 - optimization_design_lecture
            
            
    # 2022_09_22_second
        # 12:00 ~ 18:00
            12:00 ~ 12:30 - optimization_design_lecture
            12:30 ~ 13:30 - lunch
            13:30 ~ 14:00 - AGH_ppt_make
            14:00 ~ 15:00 - AGH_meeting
            15:00 ~ 18:00 - KTW_theis_learning
            
            
            

    # 2022_09_22_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - deep_reinfrocement_learning_read_book_and_make_ppt
            

    # 2022_09_22_fourth
        # 24:00 ~ 06:00  
            00:00 ~ 01:00 - deep_reinfrocement_learning_read_book_and_make_ppt
            01:00 ~ 06:00 - zzZ
            

    # do_list 
        - Graduate_school_search
        - english_plan
        - deep_reinforcement_learning_7,9,11
        - optimization_project_1,3,5
        - ansys_and_pneumatic_study
        - linux_download_needed_AGH
        - optimization_lecture_4,5
        - korea_literature_walk_project_2022_09_26
        - tire_wear_predict_human_NN_study

'''

# %%
'''

# 2022_09_23

    # 2022_09_23_first
        # 06:00 ~ 12:00
            06:00 ~ 08:30 - zzZ
            08:30 ~ 09:30 - ready
            09:30 ~ 12:00 - car_research
            
    # 2022_09_23_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - meeting_with_web_designer

    # 2022_09_23_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - YSJ_meet
            

    # 2022_09_23_fourth
        # 24:00 ~ 06:00  
            00:00 ~ 06:00 - YSJ_meet
            

    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinforcement_learning_7,9,11
        - optimization_project_1,3,5
        - ansys_and_pneumatic_study
        - linux_download_needed_AGH
        - optimization_lecture_4,5
        - korea_literature_walk_project_2022_09_26
        - tire_wear_predict_human_NN_study

'''

# %%
'''

# 2022_09_24

    # 2022_09_24_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ
            
    # 2022_09_24_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - zzZ
            13:00 ~ 15:00 - game_lol
            15:00 ~ 16:00 - lunch
            16:00 ~ 17:40 - korea_literature_walk_project
            17:40 ~ 18:00 - optimization_project_1,3,5
            

    # 2022_09_24_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - optimization_project_1,3,5
            19:00 ~ 20:00 - go_to_home
            20:00 ~ 23:00 - dinner_with_family
            23:00 ~ 24:00 - tire_wear_predict_human_NN_study
            

    # 2022_09_24_fourth
        # 24:00 ~ 06:00  
            00:00 ~ 01:00 - tire_wear_predict_meeting
            01:00 ~ 06:00 - zzZ


    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinforcement_learning_7,9,11
        - optimization_project_1,3,5
        - ansys_and_pneumatic_study
        - linux_download_needed_AGH
        - optimization_lecture_4,5
        - tire_wear_predict_human_NN_study

'''

# %%
'''

# 2022_09_25

    # 2022_09_25_first
        # 06:00 ~ 12:00
            06:00 ~ 11:00 - zzZ
            11:00 ~ 12:00 - optimization_project_1,3,5
            
            
    # 2022_09_25_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 17:00 - game_lol
            17:00 ~ 18:00 - optimization_project_1,3,5
            

    # 2022_09_25_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:20 - optimization_design_lecture
            21:20 ~ 24:00 - deep_reinforcement_learning_read_book
            

    # 2022_09_25_fourth
        # 24:00 ~ 06:00  
            00:00 ~ 01:00 - deep_reinforcement_learning_read_book
            01:00 ~ 06:00 - zzZ


    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinforcement_learning_7,9,11
        - optimization_project_1,3,5 
        - ansys_and_pneumatic_study
        - linux_download_needed_AGH
        - optimization_lecture_4,5
        - tire_wear_predict_human_NN_study

'''

# %%
'''

# 2022_09_26

    # 2022_09_26_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 10:30 - deep_reinforcement_learning_read_book
            10:30 ~ 11:00 - ready
            11:00 ~ 12:00 - KTW_meeting
            
            
    # 2022_09_26_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:30 ~ 18:00 - electronic_product_design_lecture
            

    # 2022_09_26_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - deep_reinforcement_learning_read_book
            

    # 2022_09_26_fourth
        # 24:00 ~ 06:00  
            00:00 ~ 02:00 - game_lol
            02:00 ~ 06:00 - zzZ


    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinforcement_learning_7,9,11
        - optimization_project_1,3,5
        - ansys_and_pneumatic_study
        - linux_download_needed_AGH
        - optimization_lecture_4,5
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning

'''

# %%
'''

# 2022_09_27

    # 2022_09_27_first
        # 06:00 ~ 12:00
            06:00 ~ 08:00 - zzZ
            08:00 ~ 10:30 - deep_reinforcement_learning_read_book
            10:30 ~ 11:00 - ready
            11:00 ~ 12:00 - deep_reinforcement_learning_read_book
            
            
    # 2022_09_27_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 13:30 - meeting_ready
            13:30 ~ 14:30 - KTW_meeting
            14:30 ~ 17:30 - korea_literature_walk_lecture
            17:30 ~ 18:00 - honina_talk
            

    # 2022_09_27_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - honina_talk
            19:00 ~ 21:00 - golf_lecture
            21:00 ~ 24:00 - deep_reinforcement_learning_read_book

    # 2022_09_27_fourth
        # 24:00 ~ 06:00  
            00:00 ~ 06:00 - zzZ


    # do_list
        - Graduate_school_search
        - english_plan
        - deep_reinforcement_learning_7,9,11
        - optimization_project_1,3,5
        - ansys_and_pneumatic_study
        - linux_download_needed_AGH
        - optimization_lecture_4,5
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning

'''
