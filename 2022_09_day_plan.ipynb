# %%
'''
# 2022_09_01

    # 2022_09_01_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 07:40 - ready
            07:40 ~ 08:00 - breakfirst
            08:00 ~ 08:50 - deep_reinforcement_learning_book_read
            08:50 ~ 09:30 - go_to_work
            09:30 ~ 12:00 - optimum_design_class              

    # 2022_09_01_second
        # 12:00 ~ 18:00
            12:00 ~ 12:30 - optimum_design_class
            12:30 ~ 13:30 - lunch
            13:30 ~ 14:00 - deep_reinforcement_learning_book_read
            14:00 ~ 15:00 - CJK_meeting
            15:00 ~ 18:00 - car_research
            
    # 2022_09_01_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - girlfriend_meet


    # 2022_09_01_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - deep_reinfrocement_learning_ppt
        - meeting_fee_claim
        - zig_get
        - cae_how_to_do
        - CJK_ppt_ten_per_day
        - dental_clinic
        - Paris_Baguette
        - long_t_shirt
        - credit_card
'''

# %%
'''
# 2022_09_02

    # 2022_09_02_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - CJG_ppt
            07:00 ~ 07:30 - ready
            07:30 ~ 08:00 - breakfirst
            08:00 ~ 08:50 - CJG_ppt
            08:50 ~ 09:00 - go_to_work
            09:00 ~ 12:00 - car_research             

    # 2022_09_02_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - car_research
            
    # 2022_09_02_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 23:00 - research_people_party
            23:00 ~ 24:00 - go_to_home


    # 2022_09_02_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - girl_friend_call
            00:00 ~ 06:00 - zzZ
            
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - deep_reinfrocement_learning_ppt
        - meeting_fee_claim
        - cae_how_to_do
        - CJK_ppt_ten_per_day
        - dental_clinic
        - Paris_Baguette
        - long_t_shirt
        - KTW_meeting_time
        - meeting_ParkYS
        - research_active_dayily_log
'''

# %%
'''
# 2022_09_03

    # 2022_09_03_first
        # 06:00 ~ 12:00
            06:00 ~ 10:30 - zzZ
            10:30 ~ 12:00 - ready_and_breakfirst
         
    # 2022_09_03_second
        # 12:00 ~ 18:00
            12:00 ~ 14:00 - dental_clinic
            14:00 ~ 15:00 - rest
            15:00 ~ 16:00 - read_book_deep_reinforcement_learning
            16:00 ~ 18:00 - girlfriend_call
            
            
    # 2022_09_03_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 22:00 - go_to_market
            22:00 ~ 24:00 - party_with_parents


    # 2022_09_03_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:00 - party_with_parents
            01:00 ~ 04:00 - girlfriend_call
            04:00 ~ 06:00 - zzZ
            
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - deep_reinfrocement_learning_ppt
        - meeting_fee_claim
        - cae_how_to_do
        - CJK_ppt_ten_per_day
        - Paris_Baguette
        - long_t_shirt
        - KTW_meeting_time
        - meeting_ParkYS
        - research_active_dayily_log
'''

# %%
'''
# 2022_09_05

    # 2022_09_04_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 07:30 - ready
            07:30 ~ 08:00 - breakfirst
            08:00 ~ 10:30 - deep_reinfrocement_learning_ppt
            10:50 ~ 12:00 - KTW_meeting
            
         
    # 2022_09_05_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 13:30 - PYS_meeting
            13:30 ~ 17:20 - electronic_produch_lecture            
            17:20 ~ 18:00 - 3D_CAM_lecture

    # 2022_09_05_third
        # 18:00 ~ 24:00
            18:00 ~ 20:00 - 3D_CAM_lecture
            20:00 ~ 24:00 - deep_reinfrocement_learning_ppt

    # 2022_09_05_fourth
        # 24:00 ~ 06:00
           00:00 ~ 06:00 - zzZ

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - deep_reinfrocement_learning_ppt
        - meeting_fee_claim
        - cae_how_to_do
        - CJK_ppt_ten_per_day
        - long_t_shirt
        - KTW_meeting_time
        - meeting_ParkYS
        - research_active_dayily_log
'''

# %%
'''
# 2022_09_06

    # 2022_09_06_first
        # 06:00 ~ 12:00
            06:00 ~ 10:00 - zzZ
            10:00 ~ 12:00 - ready
         
    # 2022_09_06_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 13:30 - CJG_meet
            13:30 ~ 14:20 - total_design_lecture            
            14:20 ~ 17:20 - Korea_lecture
            17:20 ~ 18:00 - dinner
            

    # 2022_09_06_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - deep_reinfrocement_learning_ppt
            19:00 ~ 21:00 - golf_lecture
            21:00 ~ 24:00 - deep_reinfrocement_learning_ppt
            
    # 2022_09_06_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - deep_reinfrocement_learning_ppt
        - cae_how_to_do
        - CJK_ppt_ten_per_day
        - long_t_shirt
        - research_active_dayily_log
        - CJK_ppt_make_start
        - electronic_smart_phone_project
        - golf_book_buy
        - korea_literature_project
'''

# %%
'''

# 2022_09_07

    # 2022_09_07_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - deep_reinfocement_learning_ppt
            09:00 ~ 12:00 - go_to_work
         
    # 2022_09_07_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 14:00 - deep_reinfocement_learning_ppt
            14:00 ~ 18:00 - ER_AGH_meeting           

    # 2022_09_07_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - golf_lecture
            21:00 ~ 24:00 - CJG_ppt
            
    # 2022_09_07_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - deep_reinfrocement_learning_ppt
        - cae_how_to_do
        - long_t_shirt
        - research_active_dayily_log
        - CJK_ppt_make_start
        - electronic_smart_phone_project
        - total_desing_meeting
        - WSJ_meeting
        - golf_book_buy
        - korea_literature_project

'''
